# %%
import pandas as pd
import os
import re

def load_and_process_json(input_file, output_file, row_limit=500):
    df = pd.read_json(input_file, lines=True)

    df = df.dropna(subset=['processed_text'])
    
    df['processed_text'] = df['processed_text'].apply(lambda x: re.sub(r'\s+', ' ', x.strip()))  # Replace multiple spaces/newlines with a single space
    df = df[df['processed_text'].str.strip() != '']  # Keep only rows with non-empty 'processed_text'

    df = df[df['processed_text'].str.len() > 10]

    print(f"Total records loaded from {input_file}: {len(df)} after cleaning")
    
    df_cleaned = df[['publish_date', 'processed_text']].dropna()

    df_sampled = df_cleaned.sample(n=row_limit, random_state=42)
    
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
    df_sampled.to_csv(output_file, index=False)
    print(f"Processed data saved to {output_file}")

input_files = [
    '../data/preprocessed/obama_preprocessed.json',
    '../data/preprocessed/trump_preprocessed.json',
    '../data/preprocessed/biden_preprocessed.json'
]

presidents = ['obama', 'trump', 'biden']
output_dir = '../flairData'

for input_file, president in zip(input_files, presidents):
    output_file = f'{output_dir}/sampled_cleaned_data_{president}.csv'
    load_and_process_json(input_file, output_file, row_limit=100)

print("Processing complete.")
# Out:
# Total records loaded from ../data/preprocessed/obama_preprocessed.json: 15704 after cleaning
# Processed data saved to ../francescoData/sampled_cleaned_data_obama.csv
# Total records loaded from ../data/preprocessed/trump_preprocessed.json: 7458 after cleaning
# Processed data saved to ../francescoData/sampled_cleaned_data_trump.csv
# Total records loaded from ../data/preprocessed/biden_preprocessed.json: 7736 after cleaning
# Processed data saved to ../francescoData/sampled_cleaned_data_biden.csv
# Processing complete.

# %%
import pandas as pd
from flair.data import Sentence
from flair.tokenization import SegtokTokenizer

tokenizer = SegtokTokenizer()

# Function to tokenize the text using Flair
def tokenize_text(text):
    if pd.isna(text):  # Check if the text is missing
        return []
    sentence = Sentence(text, use_tokenizer=tokenizer)
    tokens = [token.text for token in sentence.tokens]
    return tokens

# Function to process and tokenize data from CSV
def tokenize_from_csv(input_file, output_file):

    df = pd.read_csv(input_file)
    
    df['tokens'] = df['processed_text'].apply(tokenize_text)
    
    df[['publish_date', 'tokens']].to_csv(output_file, index=False)
    print(f"Tokenized data saved to {output_file}")

input_files = [
    '../flairData/sampled_cleaned_data_obama.csv',
    '../flairData/sampled_cleaned_data_trump.csv',
    '../flairData/sampled_cleaned_data_biden.csv'
]

output_files = [
    '../flairData/tokenized_data_obama.csv',
    '../flairData/tokenized_data_trump.csv',
    '../flairData/tokenized_data_biden.csv'
]

for input_file, output_file in zip(input_files, output_files):
    tokenize_from_csv(input_file, output_file)

print("Tokenization complete.")
# Out:
# Tokenized data saved to ../francescoData/tokenized_data_obama.csv
# Tokenized data saved to ../francescoData/tokenized_data_trump.csv
# Tokenized data saved to ../francescoData/tokenized_data_biden.csv
# Tokenization complete.

# %%
import pandas as pd
from flair.models import SequenceTagger
from flair.data import Sentence
import time
import json

tagger = SequenceTagger.load('ner')

# Function to run NER on tokenized text
def ner_on_tokens(tokens):
    sentence_text = ' '.join(tokens)  
    
    sentence = Sentence(sentence_text)
    
    tagger.predict(sentence)
    
    entities = []
    for entity in sentence.get_spans('ner'):
        entities.append({
            'text': entity.text,
            'label': entity.get_label('ner').value
        })
    return entities

# Function to process the CSV file and perform NER
def perform_ner(input_file, output_file):

    df = pd.read_csv(input_file)
    
    total_rows = len(df)
    start_time = time.time()  

    row_times = []

    for index, row in df.iterrows():
        row_start = time.time() 

        tokens = eval(row['tokens'])  
        entities = ner_on_tokens(tokens)

        df.at[index, 'entities'] = json.dumps(entities)

        row_time = time.time() - row_start
        row_times.append(row_time)

        avg_time_per_row = sum(row_times) / len(row_times)
        remaining_rows = total_rows - (index + 1)
        remaining_time = remaining_rows * avg_time_per_row

        print(f"Processed {index + 1}/{total_rows} rows. Estimated time remaining: {remaining_time:.2f} seconds")

    df[['publish_date', 'entities']].to_csv(output_file, index=False)
    
    total_time = time.time() - start_time
    print(f"NER results saved to {output_file}. Total time: {total_time:.2f} seconds")

input_files = [
    '../flairData/tokenized_data_obama.csv',
    '../flairData/tokenized_data_trump.csv',
    '../flairData/tokenized_data_biden.csv'
]

output_files = [
    '../flairData/ner_results_obama.csv',
    '../flairData/ner_results_trump.csv',
    '../flairData/ner_results_biden.csv'
]

for input_file, output_file in zip(input_files, output_files):
    perform_ner(input_file, output_file)

print("NER process complete.")
# Out:
# 2024-10-11 15:28:49,033 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# Processed 1/100 rows. Estimated time remaining: 1056.40 seconds
# Processed 2/100 rows. Estimated time remaining: 851.89 seconds
# Processed 3/100 rows. Estimated time remaining: 3938.84 seconds
# Processed 4/100 rows. Estimated time remaining: 3010.81 seconds
# Processed 5/100 rows. Estimated time remaining: 2509.44 seconds
# Processed 6/100 rows. Estimated time remaining: 2143.67 seconds
# Processed 7/100 rows. Estimated time remaining: 1845.53 seconds
# Processed 8/100 rows. Estimated time remaining: 1638.61 seconds
# Processed 9/100 rows. Estimated time remaining: 1679.28 seconds
# Processed 10/100 rows. Estimated time remaining: 1559.03 seconds
# Processed 11/100 rows. Estimated time remaining: 1429.36 seconds
# Processed 12/100 rows. Estimated time remaining: 1323.30 seconds
# Processed 13/100 rows. Estimated time remaining: 1269.64 seconds
# Processed 14/100 rows. Estimated time remaining: 1219.58 seconds
# Processed 15/100 rows. Estimated time remaining: 1158.12 seconds
# Processed 16/100 rows. Estimated time remaining: 1129.67 seconds
# Processed 17/100 rows. Estimated time remaining: 1058.29 seconds
# Processed 18/100 rows. Estimated time remaining: 1030.46 seconds
# Processed 19/100 rows. Estimated time remaining: 995.82 seconds
# Processed 20/100 rows. Estimated time remaining: 953.85 seconds
# Processed 21/100 rows. Estimated time remaining: 914.22 seconds
# Processed 22/100 rows. Estimated time remaining: 910.42 seconds
# Processed 23/100 rows. Estimated time remaining: 868.79 seconds
# Processed 24/100 rows. Estimated time remaining: 849.53 seconds
# Processed 25/100 rows. Estimated time remaining: 828.36 seconds
# Processed 26/100 rows. Estimated time remaining: 800.32 seconds
# Processed 27/100 rows. Estimated time remaining: 772.88 seconds
# Processed 28/100 rows. Estimated time remaining: 761.28 seconds
# Processed 29/100 rows. Estimated time remaining: 1008.78 seconds
# Processed 30/100 rows. Estimated time remaining: 968.48 seconds
# Processed 31/100 rows. Estimated time remaining: 930.19 seconds
# Processed 32/100 rows. Estimated time remaining: 902.89 seconds
# Processed 33/100 rows. Estimated time remaining: 873.55 seconds
# Processed 34/100 rows. Estimated time remaining: 842.48 seconds
# Processed 35/100 rows. Estimated time remaining: 837.43 seconds
# Processed 36/100 rows. Estimated time remaining: 805.75 seconds
# Processed 37/100 rows. Estimated time remaining: 783.29 seconds
# Processed 38/100 rows. Estimated time remaining: 758.01 seconds
# Processed 39/100 rows. Estimated time remaining: 738.62 seconds
# Processed 40/100 rows. Estimated time remaining: 747.63 seconds
# Processed 41/100 rows. Estimated time remaining: 765.78 seconds
# Processed 42/100 rows. Estimated time remaining: 744.74 seconds
# Processed 43/100 rows. Estimated time remaining: 720.08 seconds
# Processed 44/100 rows. Estimated time remaining: 694.56 seconds
# Processed 45/100 rows. Estimated time remaining: 702.11 seconds
# Processed 46/100 rows. Estimated time remaining: 796.32 seconds
# Processed 47/100 rows. Estimated time remaining: 771.30 seconds
# Processed 48/100 rows. Estimated time remaining: 744.15 seconds
# Processed 49/100 rows. Estimated time remaining: 721.22 seconds
# Processed 50/100 rows. Estimated time remaining: 700.40 seconds
# Processed 51/100 rows. Estimated time remaining: 674.49 seconds
# Processed 52/100 rows. Estimated time remaining: 655.76 seconds
# Processed 53/100 rows. Estimated time remaining: 635.46 seconds
# Processed 54/100 rows. Estimated time remaining: 621.94 seconds
# Processed 55/100 rows. Estimated time remaining: 603.70 seconds
# Processed 56/100 rows. Estimated time remaining: 652.34 seconds
# Processed 57/100 rows. Estimated time remaining: 631.05 seconds
# Processed 58/100 rows. Estimated time remaining: 609.30 seconds
# Processed 59/100 rows. Estimated time remaining: 588.04 seconds
# Processed 60/100 rows. Estimated time remaining: 568.27 seconds
# Processed 61/100 rows. Estimated time remaining: 575.63 seconds
# Processed 62/100 rows. Estimated time remaining: 553.94 seconds
# Processed 63/100 rows. Estimated time remaining: 533.02 seconds
# Processed 64/100 rows. Estimated time remaining: 514.76 seconds
# Processed 65/100 rows. Estimated time remaining: 497.02 seconds
# Processed 66/100 rows. Estimated time remaining: 476.92 seconds
# Processed 67/100 rows. Estimated time remaining: 457.85 seconds
# Processed 68/100 rows. Estimated time remaining: 446.60 seconds
# Processed 69/100 rows. Estimated time remaining: 430.04 seconds
# Processed 70/100 rows. Estimated time remaining: 412.70 seconds
# Processed 71/100 rows. Estimated time remaining: 398.11 seconds
# Processed 72/100 rows. Estimated time remaining: 386.38 seconds
# Processed 73/100 rows. Estimated time remaining: 368.69 seconds
# Processed 74/100 rows. Estimated time remaining: 351.57 seconds
# Processed 75/100 rows. Estimated time remaining: 335.45 seconds
# Processed 76/100 rows. Estimated time remaining: 318.90 seconds
# Processed 77/100 rows. Estimated time remaining: 321.08 seconds
# Processed 78/100 rows. Estimated time remaining: 340.13 seconds
# Processed 79/100 rows. Estimated time remaining: 321.54 seconds
# Processed 80/100 rows. Estimated time remaining: 303.80 seconds
# Processed 81/100 rows. Estimated time remaining: 300.40 seconds
# Processed 82/100 rows. Estimated time remaining: 292.70 seconds
# Processed 83/100 rows. Estimated time remaining: 281.76 seconds
# Processed 84/100 rows. Estimated time remaining: 262.90 seconds
# Processed 85/100 rows. Estimated time remaining: 246.12 seconds
# Processed 86/100 rows. Estimated time remaining: 227.77 seconds
# Processed 87/100 rows. Estimated time remaining: 210.72 seconds
# Processed 88/100 rows. Estimated time remaining: 193.06 seconds
# Processed 89/100 rows. Estimated time remaining: 176.11 seconds
# Processed 90/100 rows. Estimated time remaining: 158.95 seconds
# Processed 91/100 rows. Estimated time remaining: 141.80 seconds
# Processed 92/100 rows. Estimated time remaining: 125.22 seconds
# Processed 93/100 rows. Estimated time remaining: 109.01 seconds
# Processed 94/100 rows. Estimated time remaining: 92.64 seconds
# Processed 95/100 rows. Estimated time remaining: 81.85 seconds
# Processed 96/100 rows. Estimated time remaining: 73.62 seconds
# Processed 97/100 rows. Estimated time remaining: 54.98 seconds
# Processed 98/100 rows. Estimated time remaining: 37.23 seconds
# Processed 99/100 rows. Estimated time remaining: 18.51 seconds
# Processed 100/100 rows. Estimated time remaining: 0.00 seconds
# NER results saved to ../francescoData/ner_results_obama.csv. Total time: 1839.14 seconds
# Processed 1/100 rows. Estimated time remaining: 229.36 seconds
# Processed 2/100 rows. Estimated time remaining: 5898.31 seconds
# Processed 3/100 rows. Estimated time remaining: 5123.30 seconds
# Processed 4/100 rows. Estimated time remaining: 3932.79 seconds
# Processed 5/100 rows. Estimated time remaining: 3191.81 seconds
# Processed 6/100 rows. Estimated time remaining: 2772.62 seconds
# Processed 7/100 rows. Estimated time remaining: 2665.60 seconds
# Processed 8/100 rows. Estimated time remaining: 2343.59 seconds
# Processed 9/100 rows. Estimated time remaining: 2172.62 seconds
# Processed 10/100 rows. Estimated time remaining: 1972.17 seconds
# Processed 11/100 rows. Estimated time remaining: 1863.23 seconds
# Processed 12/100 rows. Estimated time remaining: 1746.89 seconds
# Processed 13/100 rows. Estimated time remaining: 1622.00 seconds
# Processed 14/100 rows. Estimated time remaining: 1505.16 seconds
# Processed 15/100 rows. Estimated time remaining: 1406.28 seconds
# Processed 16/100 rows. Estimated time remaining: 1314.99 seconds
# Processed 17/100 rows. Estimated time remaining: 1377.84 seconds
# Processed 18/100 rows. Estimated time remaining: 1307.40 seconds
# Processed 19/100 rows. Estimated time remaining: 1232.77 seconds
# Processed 20/100 rows. Estimated time remaining: 1314.11 seconds
# Processed 21/100 rows. Estimated time remaining: 1298.98 seconds
# Processed 22/100 rows. Estimated time remaining: 1266.31 seconds
# Processed 23/100 rows. Estimated time remaining: 1421.14 seconds
# Processed 24/100 rows. Estimated time remaining: 1356.00 seconds
# Processed 25/100 rows. Estimated time remaining: 1306.57 seconds
# Processed 26/100 rows. Estimated time remaining: 1249.12 seconds
# Processed 27/100 rows. Estimated time remaining: 1208.85 seconds
# Processed 28/100 rows. Estimated time remaining: 1164.69 seconds
# Processed 29/100 rows. Estimated time remaining: 1124.38 seconds
# Processed 30/100 rows. Estimated time remaining: 1078.28 seconds
# Processed 31/100 rows. Estimated time remaining: 1051.03 seconds
# Processed 32/100 rows. Estimated time remaining: 1230.09 seconds
# Processed 33/100 rows. Estimated time remaining: 1310.89 seconds
# Processed 34/100 rows. Estimated time remaining: 1282.53 seconds
# Processed 35/100 rows. Estimated time remaining: 1241.72 seconds
# Processed 36/100 rows. Estimated time remaining: 1193.19 seconds
# Processed 37/100 rows. Estimated time remaining: 1169.67 seconds
# Processed 38/100 rows. Estimated time remaining: 1124.19 seconds
# Processed 39/100 rows. Estimated time remaining: 1148.62 seconds
# Processed 40/100 rows. Estimated time remaining: 1105.68 seconds
# Processed 41/100 rows. Estimated time remaining: 1068.12 seconds
# Processed 42/100 rows. Estimated time remaining: 1035.15 seconds
# Processed 43/100 rows. Estimated time remaining: 1053.64 seconds
# Processed 44/100 rows. Estimated time remaining: 1020.04 seconds
# Processed 45/100 rows. Estimated time remaining: 983.08 seconds
# Processed 46/100 rows. Estimated time remaining: 1010.27 seconds
# Processed 47/100 rows. Estimated time remaining: 974.24 seconds
# Processed 48/100 rows. Estimated time remaining: 990.96 seconds
# Processed 49/100 rows. Estimated time remaining: 964.74 seconds
# Processed 50/100 rows. Estimated time remaining: 943.59 seconds
# Processed 51/100 rows. Estimated time remaining: 909.49 seconds
# Processed 52/100 rows. Estimated time remaining: 879.76 seconds
# Processed 53/100 rows. Estimated time remaining: 928.43 seconds
# Processed 54/100 rows. Estimated time remaining: 946.47 seconds
# Processed 55/100 rows. Estimated time remaining: 914.08 seconds
# Processed 56/100 rows. Estimated time remaining: 905.86 seconds
# Processed 57/100 rows. Estimated time remaining: 899.04 seconds
# Processed 58/100 rows. Estimated time remaining: 868.17 seconds
# Processed 59/100 rows. Estimated time remaining: 867.80 seconds
# Processed 60/100 rows. Estimated time remaining: 839.91 seconds
# Processed 61/100 rows. Estimated time remaining: 823.73 seconds
# Processed 62/100 rows. Estimated time remaining: 791.47 seconds
# Processed 63/100 rows. Estimated time remaining: 792.98 seconds
# Processed 64/100 rows. Estimated time remaining: 761.78 seconds
# Processed 65/100 rows. Estimated time remaining: 732.53 seconds
# Processed 66/100 rows. Estimated time remaining: 704.20 seconds
# Processed 67/100 rows. Estimated time remaining: 704.25 seconds
# Processed 68/100 rows. Estimated time remaining: 676.82 seconds
# Processed 69/100 rows. Estimated time remaining: 664.43 seconds
# Processed 70/100 rows. Estimated time remaining: 691.40 seconds
# Processed 71/100 rows. Estimated time remaining: 664.57 seconds
# Processed 72/100 rows. Estimated time remaining: 633.93 seconds
# Processed 73/100 rows. Estimated time remaining: 605.16 seconds
# Processed 74/100 rows. Estimated time remaining: 579.04 seconds
# Processed 75/100 rows. Estimated time remaining: 550.95 seconds
# Processed 76/100 rows. Estimated time remaining: 524.14 seconds
# Processed 77/100 rows. Estimated time remaining: 505.36 seconds
# Processed 78/100 rows. Estimated time remaining: 477.83 seconds
# Processed 79/100 rows. Estimated time remaining: 451.14 seconds
# Processed 80/100 rows. Estimated time remaining: 425.27 seconds
# Processed 81/100 rows. Estimated time remaining: 399.74 seconds
# Processed 82/100 rows. Estimated time remaining: 374.70 seconds
# Processed 83/100 rows. Estimated time remaining: 403.74 seconds
# Processed 84/100 rows. Estimated time remaining: 390.16 seconds
# Processed 85/100 rows. Estimated time remaining: 361.78 seconds
# Processed 86/100 rows. Estimated time remaining: 334.40 seconds
# Processed 87/100 rows. Estimated time remaining: 307.87 seconds
# Processed 88/100 rows. Estimated time remaining: 284.06 seconds
# Processed 89/100 rows. Estimated time remaining: 259.88 seconds
# Processed 90/100 rows. Estimated time remaining: 233.90 seconds
# Processed 91/100 rows. Estimated time remaining: 208.80 seconds
# Processed 92/100 rows. Estimated time remaining: 183.90 seconds
# Processed 93/100 rows. Estimated time remaining: 159.61 seconds
# Processed 94/100 rows. Estimated time remaining: 135.68 seconds
# Processed 95/100 rows. Estimated time remaining: 112.10 seconds
# Processed 96/100 rows. Estimated time remaining: 88.97 seconds
# Processed 97/100 rows. Estimated time remaining: 66.10 seconds
# Processed 98/100 rows. Estimated time remaining: 44.32 seconds
# Processed 99/100 rows. Estimated time remaining: 22.18 seconds
# Processed 100/100 rows. Estimated time remaining: 0.00 seconds
# NER results saved to ../francescoData/ner_results_trump.csv. Total time: 2202.73 seconds
# Processed 1/100 rows. Estimated time remaining: 395.90 seconds
# Processed 2/100 rows. Estimated time remaining: 1955.35 seconds
# Processed 3/100 rows. Estimated time remaining: 1478.81 seconds
# Processed 4/100 rows. Estimated time remaining: 1215.10 seconds
# Processed 5/100 rows. Estimated time remaining: 1142.18 seconds
# Processed 6/100 rows. Estimated time remaining: 1067.00 seconds
# Processed 7/100 rows. Estimated time remaining: 935.70 seconds
# Processed 8/100 rows. Estimated time remaining: 1250.30 seconds
# Processed 9/100 rows. Estimated time remaining: 2050.04 seconds
# Processed 10/100 rows. Estimated time remaining: 1857.94 seconds
# Processed 11/100 rows. Estimated time remaining: 1693.57 seconds
# Processed 12/100 rows. Estimated time remaining: 1557.81 seconds
# Processed 13/100 rows. Estimated time remaining: 1513.14 seconds
# Processed 14/100 rows. Estimated time remaining: 1433.66 seconds
# Processed 15/100 rows. Estimated time remaining: 2373.91 seconds
# Processed 16/100 rows. Estimated time remaining: 2214.56 seconds
# Processed 17/100 rows. Estimated time remaining: 2087.49 seconds
# Processed 18/100 rows. Estimated time remaining: 1978.84 seconds
# Processed 19/100 rows. Estimated time remaining: 1865.77 seconds
# Processed 20/100 rows. Estimated time remaining: 1784.44 seconds
# Processed 21/100 rows. Estimated time remaining: 1696.10 seconds
# Processed 22/100 rows. Estimated time remaining: 1618.09 seconds
# Processed 23/100 rows. Estimated time remaining: 1534.04 seconds
# Processed 24/100 rows. Estimated time remaining: 1477.54 seconds
# Processed 25/100 rows. Estimated time remaining: 1463.92 seconds
# Processed 26/100 rows. Estimated time remaining: 1401.39 seconds
# Processed 27/100 rows. Estimated time remaining: 1337.57 seconds
# Processed 28/100 rows. Estimated time remaining: 1298.14 seconds
# Processed 29/100 rows. Estimated time remaining: 1258.56 seconds
# Processed 30/100 rows. Estimated time remaining: 1205.95 seconds
# Processed 31/100 rows. Estimated time remaining: 1187.43 seconds
# Processed 32/100 rows. Estimated time remaining: 1151.53 seconds
# Processed 33/100 rows. Estimated time remaining: 1125.98 seconds
# Processed 34/100 rows. Estimated time remaining: 1089.17 seconds
# Processed 35/100 rows. Estimated time remaining: 1045.80 seconds
# Processed 36/100 rows. Estimated time remaining: 1006.87 seconds
# Processed 37/100 rows. Estimated time remaining: 969.39 seconds
# Processed 38/100 rows. Estimated time remaining: 941.81 seconds
# Processed 39/100 rows. Estimated time remaining: 932.06 seconds
# Processed 40/100 rows. Estimated time remaining: 924.59 seconds
# Processed 41/100 rows. Estimated time remaining: 910.07 seconds
# Processed 42/100 rows. Estimated time remaining: 880.70 seconds
# Processed 43/100 rows. Estimated time remaining: 864.89 seconds
# Processed 44/100 rows. Estimated time remaining: 835.22 seconds
# Processed 45/100 rows. Estimated time remaining: 806.12 seconds
# Processed 46/100 rows. Estimated time remaining: 779.68 seconds
# Processed 47/100 rows. Estimated time remaining: 791.10 seconds
# Processed 48/100 rows. Estimated time remaining: 763.44 seconds
# Processed 49/100 rows. Estimated time remaining: 737.28 seconds
# Processed 50/100 rows. Estimated time remaining: 711.20 seconds
# Processed 51/100 rows. Estimated time remaining: 687.27 seconds
# Processed 52/100 rows. Estimated time remaining: 681.72 seconds
# Processed 53/100 rows. Estimated time remaining: 685.84 seconds
# Processed 54/100 rows. Estimated time remaining: 663.66 seconds
# Processed 55/100 rows. Estimated time remaining: 640.62 seconds
# Processed 56/100 rows. Estimated time remaining: 619.65 seconds
# Processed 57/100 rows. Estimated time remaining: 596.57 seconds
# Processed 58/100 rows. Estimated time remaining: 574.55 seconds
# Processed 59/100 rows. Estimated time remaining: 563.79 seconds
# Processed 60/100 rows. Estimated time remaining: 542.79 seconds
# Processed 61/100 rows. Estimated time remaining: 523.64 seconds
# Processed 62/100 rows. Estimated time remaining: 506.23 seconds
# Processed 63/100 rows. Estimated time remaining: 486.76 seconds
# Processed 64/100 rows. Estimated time remaining: 469.37 seconds
# Processed 65/100 rows. Estimated time remaining: 451.50 seconds
# Processed 66/100 rows. Estimated time remaining: 433.56 seconds
# Processed 67/100 rows. Estimated time remaining: 415.81 seconds
# Processed 68/100 rows. Estimated time remaining: 399.52 seconds
# Processed 69/100 rows. Estimated time remaining: 383.32 seconds
# Processed 70/100 rows. Estimated time remaining: 369.90 seconds
# Processed 71/100 rows. Estimated time remaining: 355.49 seconds
# Processed 72/100 rows. Estimated time remaining: 339.71 seconds
# Processed 73/100 rows. Estimated time remaining: 324.95 seconds
# Processed 74/100 rows. Estimated time remaining: 309.90 seconds
# Processed 75/100 rows. Estimated time remaining: 295.26 seconds
# Processed 76/100 rows. Estimated time remaining: 281.41 seconds
# Processed 77/100 rows. Estimated time remaining: 266.59 seconds
# Processed 78/100 rows. Estimated time remaining: 252.77 seconds
# Processed 79/100 rows. Estimated time remaining: 239.70 seconds
# Processed 80/100 rows. Estimated time remaining: 227.67 seconds
# Processed 81/100 rows. Estimated time remaining: 214.31 seconds
# Processed 82/100 rows. Estimated time remaining: 201.42 seconds
# Processed 83/100 rows. Estimated time remaining: 189.71 seconds
# Processed 84/100 rows. Estimated time remaining: 176.85 seconds
# Processed 85/100 rows. Estimated time remaining: 164.57 seconds
# Processed 86/100 rows. Estimated time remaining: 152.83 seconds
# Processed 87/100 rows. Estimated time remaining: 140.94 seconds
# Processed 88/100 rows. Estimated time remaining: 129.42 seconds
# Processed 89/100 rows. Estimated time remaining: 117.71 seconds
# Processed 90/100 rows. Estimated time remaining: 121.04 seconds
# Processed 91/100 rows. Estimated time remaining: 108.51 seconds
# Processed 92/100 rows. Estimated time remaining: 95.63 seconds
# Processed 93/100 rows. Estimated time remaining: 84.54 seconds
# Processed 94/100 rows. Estimated time remaining: 72.30 seconds
# Processed 95/100 rows. Estimated time remaining: 59.85 seconds
# Processed 96/100 rows. Estimated time remaining: 48.35 seconds
# Processed 97/100 rows. Estimated time remaining: 36.17 seconds
# Processed 98/100 rows. Estimated time remaining: 24.23 seconds
# Processed 99/100 rows. Estimated time remaining: 12.05 seconds
# Processed 100/100 rows. Estimated time remaining: 0.00 seconds
# NER results saved to ../francescoData/ner_results_biden.csv. Total time: 1211.63 seconds
# NER process complete.
